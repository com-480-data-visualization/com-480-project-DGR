# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
import json
import random
import requests
import pandas as pd
from tqdm import tqdm
from functools import lru_cache

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
@lru_cache(maxsize=100000)
def convert_samplingpoint_to_city(lat, lon):
    """
    Convert sampling point data to city data.
    """
    # Load the sampling point data
    url = "https://nominatim.openstreetmap.org/reverse"
    params = {
        "format": "jsonv2",
        "lat": lat,
        "lon": lon,
        "zoom": 10,  # Slightly more detailed than 10, still returns cities
        "addressdetails": 1
    }
    headers = {
        "User-Agent": "YourAppName/1.0 (drudao.2001@gmail.com)"
    }

    try:
        print(f"Fetching city for coordinates: ({lat}, {lon})")
        response = requests.get(url, params=params, headers=headers)
        response.raise_for_status()
        data = response.json()
        address = data.get("address", {})

        # Return most appropriate field available
        return (
            address.get("city") or
            address.get("town") or
            address.get("village") or
            address.get("municipality") or
            address.get("county") or
            None
        )

    except requests.RequestException as e:
        print(f"Error: {e}")
        return None

# %%
def retry_with_backoff(func, *args, max_retries=5, **kwargs):
    for attempt in range(max_retries):
        result = func(*args, **kwargs)
        if result:
            return result
        wait_time = 2 ** attempt + random.uniform(0, 1)
        print(f"Retrying in {wait_time:.2f}s...")
        time.sleep(wait_time)
    return None

# %%
def add_city_to_data(file_path):
    """
    Adds a 'City' field to each sampling point in a JSON file using reverse geocoding.

    Args:
        file_path (str): The path to the input JSON file.

    Returns:
        str: The path to the new JSON file with added city information,
             or None if an error occurs.
    """
    try:
        with open(file_path, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return None
    except json.JSONDecodeError:
        print(f"Error: Could not decode JSON from {file_path}")
        return None

    geolocator = Nominatim(user_agent="city_finder_app")
    reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1, error_wait_seconds=10, max_retries=2)

    updated_data_count = 0
    failed_lookups = 0

    print("Starting to process the data for city information...")

    for year_data in tqdm(data.values()):
        for pollutant_data in year_data.values():
            for country_data_list in pollutant_data.values():
                for entry in country_data_list:
                    if 'Latitude' in entry and 'Longitude' in entry:
                        lat = entry['Latitude']
                        lon = entry['Longitude']
                        location = None
                        try:
                            # Ensure coordinates are valid numbers
                            if isinstance(lat, (int, float)) and isinstance(lon, (int, float)):
                                location = reverse((lat, lon), language='en', timeout=10) # Added timeout
                                if location and location.raw.get('address'):
                                    address = location.raw['address']
                                    # Prioritize city, then town, then village
                                    city = address.get('city', address.get('town', address.get('village')))
                                    if city:
                                        entry['City'] = city
                                        print(f"Found city: {city} for Lat: {lat}, Lon: {lon}")
                                        updated_data_count +=1
                                    else:
                                        print(f"City not found in address for Lat: {lat}, Lon: {lon}. Address: {address}")
                                        entry['City'] = 'N/A' # Not Available
                                        failed_lookups +=1
                                        print(f"City not found for Lat: {lat}, Lon: {lon}. Address: {address}")
                                else:
                                    print(f"Location not found for Lat: {lat}, Lon: {lon}")
                                    entry['City'] = 'N/A'
                                    failed_lookups +=1
                                    print(f"Location or address not found for Lat: {lat}, Lon: {lon}")
                            else:
                                print(f"Invalid coordinates for entry: {entry.get('Samplingpoint')}")
                                entry['City'] = 'Invalid Coords'
                                failed_lookups +=1
                                print(f"Invalid coordinates for entry: {entry.get('Samplingpoint')}")
                        except Exception as e:
                            entry['City'] = 'Error'
                            failed_lookups +=1
                            print(f"Error during geocoding for Lat: {lat}, Lon: {lon} - {e}")
                        # Adding a small delay to be respectful to the Nominatim API
                        time.sleep(0.5) # Sleep for 0.5 second between requests

    print(f"Successfully added city information to {updated_data_count} entries.")
    if failed_lookups > 0:
        print(f"Could not determine city for {failed_lookups} entries (marked as 'N/A', 'Invalid Coords', or 'Error').")

    output_file_path = "air_quality_data_with_cities.json"
    try:
        with open(output_file_path, 'w') as f:
            json.dump(data, f, indent=2)
        print(f"Successfully generated the new JSON file: {output_file_path}")
        return output_file_path
    except IOError:
        print(f"Error: Could not write to {output_file_path}")
        return None

# %%
add_city_to_data("../data/air_quality_data.json")
# Out:
# Starting to process the data for city information...
#   0%|          | 0/31 [00:00<?, ?it/s]
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
#   3%|▎         | 1/31 [00:21<10:42, 21.42s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Voitsberg for Lat: 47.04472, Lon: 15.15278
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
#   6%|▋         | 2/31 [01:03<16:14, 33.60s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Voitsberg for Lat: 47.04472, Lon: 15.15278
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
#  10%|▉         | 3/31 [01:47<17:53, 38.33s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Lienz for Lat: 46.82773, Lon: 12.76562
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Voitsberg for Lat: 47.04472, Lon: 15.15278
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
#  13%|█▎        | 4/31 [02:50<21:36, 48.03s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Lienz for Lat: 46.82773, Lon: 12.76562
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Voitsberg for Lat: 47.04472, Lon: 15.15278
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
#  16%|█▌        | 5/31 [03:49<22:35, 52.12s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Linz for Lat: 48.27329, Lon: 14.31479
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Linz for Lat: 48.27329, Lon: 14.31479
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Lienz for Lat: 46.82773, Lon: 12.76562
# Found city: Vienna for Lat: 48.14128, Lon: 16.29259
# Found city: Vienna for Lat: 48.18837, Lon: 16.30002
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Linz for Lat: 48.27329, Lon: 14.31479
# Found city: Voitsberg for Lat: 47.04472, Lon: 15.15278
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
# Found city: Lienz for Lat: 46.81911, Lon: 12.76603
# Found city: Vienna for Lat: 48.20815, Lon: 16.37325
#  19%|█▉        | 6/31 [04:31<20:10, 48.43s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Lienz for Lat: 46.82773, Lon: 12.76562
# Found city: Vienna for Lat: 48.14128, Lon: 16.29259
# Found city: Vienna for Lat: 48.18837, Lon: 16.30002
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Braunau am Inn for Lat: 48.25747, Lon: 13.03923
# Found city: Voitsberg for Lat: 47.04472, Lon: 15.15278
# Found city: Pöllauberg for Lat: 47.34806, Lon: 15.88222
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
# Found city: Lienz for Lat: 46.81911, Lon: 12.76603
# Found city: Vienna for Lat: 48.20815, Lon: 16.37325
#  23%|██▎       | 7/31 [05:10<18:09, 45.38s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Vienna for Lat: 48.14128, Lon: 16.29259
# Found city: Vienna for Lat: 48.18837, Lon: 16.30002
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Lamm for Lat: 47.13378, Lon: 13.54318
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
# Found city: Lienz for Lat: 46.81911, Lon: 12.76603
# Found city: Vienna for Lat: 48.20815, Lon: 16.37325
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Bruck an der Mur for Lat: 47.409440000000004, Lon: 15.25333
#  26%|██▌       | 8/31 [05:39<15:23, 40.16s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: St. Pölten for Lat: 48.20113, Lon: 15.62
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Vienna for Lat: 48.14128, Lon: 16.29259
# Found city: Vienna for Lat: 48.18837, Lon: 16.30002
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Lamm for Lat: 47.13378, Lon: 13.54318
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
# Found city: Lienz for Lat: 46.81911, Lon: 12.76603
# Found city: Vienna for Lat: 48.20815, Lon: 16.37325
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Knittelfeld for Lat: 47.21037, Lon: 14.82528
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Bruck an der Mur for Lat: 47.409440000000004, Lon: 15.25333
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
#  29%|██▉       | 9/31 [06:13<14:05, 38.43s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: St. Pölten for Lat: 48.20113, Lon: 15.62
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Vienna for Lat: 48.14128, Lon: 16.29259
# Found city: Vienna for Lat: 48.18837, Lon: 16.30002
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Lamm for Lat: 47.13378, Lon: 13.54318
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Oberhaag for Lat: 46.65195, Lon: 15.36778
# Found city: Lienz for Lat: 46.81911, Lon: 12.76603
# Found city: Vienna for Lat: 48.20815, Lon: 16.37325
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Bruck an der Mur for Lat: 47.409440000000004, Lon: 15.25333
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
#  32%|███▏      | 10/31 [06:45<12:42, 36.33s/it]
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Hartberg for Lat: 47.28286, Lon: 15.97185
# Found city: Bruck an der Mur for Lat: 47.409440000000004, Lon: 15.25333
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city: St. Pölten for Lat: 48.20113, Lon: 15.62
# Found city: Steyregg for Lat: 48.27975, Lon: 14.3665
# Found city: Graz for Lat: 47.04172, Lon: 15.43308
# Found city: Liezen for Lat: 47.56544, Lon: 14.24468
# Found city: Weiz for Lat: 47.2157, Lon: 15.62839
# Found city: Kufstein for Lat: 47.58181, Lon: 12.17241
# Found city: Vienna for Lat: 48.14128, Lon: 16.29259
# Found city: Vienna for Lat: 48.18837, Lon: 16.30002
# Found city: Klagenfurt for Lat: 46.62662, Lon: 14.29914
# Found city: Klosterneuburg for Lat: 48.30194, Lon: 16.32111
# Found city: Tulln an der Donau for Lat: 48.33004, Lon: 16.05726
# Found city:
# Found city: Bellver de Cerdanya for Lat: 42.3683, Lon: 1.7768000000000002
# Found city: Lleida for Lat: 41.6158, Lon: 0.6157
# Found city: Ponts for Lat: 41.90665, Lon: 1.19297
# Found city: els Torms for Lat: 41.39333, Lon: 0.7341700000000001
# Found city: Alfaro for Lat: 42.176, Lon: -1.744
# Found city: Arrúbal for Lat: 42.44, Lon: -2.239
# Found city: Galilea for Lat: 42.341, Lon: -2.232
# Found city: Logroño for Lat: 42.464, Lon: -2.428
# Found city: Pradejón for Lat: 42.34, Lon: -2.059
# Found city: Lugo for Lat: 42.9979, Lon: -7.5509
# City not found in address for Lat: 43.5329, Lon: -7.7377. Address: {'road': 'LU-P-3405', 'civil_parish': 'Ambosores', 'hamlet': 'Muras', 'county': 'Terra Chá', 'province': 'Lugo', 'ISO3166-2-lvl6': 'ES-LU', 'state': 'Galicia', 'ISO3166-2-lvl4': 'ES-GA', 'postcode': '15399', 'country': 'Spain', 'country_code': 'es'}
# City not found for Lat: 43.5329, Lon: -7.7377. Address: {'road': 'LU-P-3405', 'civil_parish': 'Ambosores', 'hamlet': 'Muras', 'county': 'Terra Chá', 'province': 'Lugo', 'ISO3166-2-lvl6': 'ES-LU', 'state': 'Galicia', 'ISO3166-2-lvl4': 'ES-GA', 'postcode': '15399', 'country': 'Spain', 'country_code': 'es'}
# City not found in address for Lat: 42.63472, Lon: -7.70458. Address: {'hamlet': 'A Lagoa', 'civil_parish': 'Rebordaos', 'municipality': 'O Saviñao', 'county': 'Terra de Lemos', 'province': 'Lugo', 'ISO3166-2-lvl6': 'ES-LU', 'state': 'Galicia', 'ISO3166-2-lvl4': 'ES-GA', 'postcode': '27594', 'country': 'Spain', 'country_code': 'es'}
# City not found for Lat: 42.63472, Lon: -7.70458. Address: {'hamlet': 'A Lagoa', 'civil_parish': 'Rebordaos', 'municipality': 'O Saviñao', 'county': 'Terra de Lemos', 'province': 'Lugo', 'ISO3166-2-lvl6': 'ES-LU', 'state': 'Galicia', 'ISO3166-2-lvl4': 'ES-GA', 'postcode': '27594', 'country': 'Spain', 'country_code': 'es'}
# Found city: Vilalba for Lat: 43.313, Lon: -7.6937
# Found city: Alcalá de Henares for Lat: 40.47933, Lon: -3.3779500000000002
# Found city: Alcobendas for Lat: 40.54035, Lon: -3.64525
# Found city: Alcorcón for Lat: 40.3419, Lon: -3.8337
# Found city: Algete for Lat: 40.5997, Lon: -3.5033
# Found city: Aranjuez for Lat: 40.03327, Lon: -3.5914
# Found city: Arganda del Rey for Lat: 40.30069, Lon: -3.45883
# Found city: Patones for Lat: 40.909, Lon: -3.4679
# Found city: Colmenar Viejo for Lat: 40.6646, Lon: -3.7739000000000003
# Found city: Collado Villalba for Lat: 40.6339, Lon: -4.01425
# Found city: Coslada for Lat: 40.4306, Lon: -3.5423999999999998
# Found city: Fuenlabrada for Lat: 40.28151, Lon: -3.8009500000000003
# Found city: Guadalix de la Sierra for Lat: 40.78063, Lon: -3.70215
/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 add_city_to_data("../data/air_quality_data.json")
#
# Cell In[7], line 41, in add_city_to_data(file_path)
#      38 try:
#      39     # Ensure coordinates are valid numbers
#      40     if isinstance(lat, (int, float)) and isinstance(lon, (int, float)):
# ---> 41         location = reverse((lat, lon), language='en', timeout=10) # Added timeout
#      42         if location and location.raw.get('address'):
#      43             address = location.raw['address']
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/geopy/extra/rate_limiter.py:274, in RateLimiter.__call__(self, *args, **kwargs)
#     272 self._acquire_request_slot()
#     273 try:
# --> 274     res = self.func(*args, **kwargs)
#     275     if inspect.isawaitable(res):
#     276         raise ValueError(
#     277             "An async awaitable has been passed to `RateLimiter`. "
#     278             "Use `AsyncRateLimiter` instead, which supports awaitables."
#     279         )
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/geopy/geocoders/nominatim.py:372, in Nominatim.reverse(self, query, exactly_one, timeout, language, addressdetails, zoom, namedetails)
#     370 logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     371 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 372 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/geopy/geocoders/base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/geopy/adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#     474         return resp.json()
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/geopy/adapters.py:482, in RequestsAdapter._request(self, url, timeout, headers)
#     480 def _request(self, url, *, timeout, headers):
#     481     try:
# --> 482         resp = self.session.get(url, timeout=timeout, headers=headers)
#     483     except Exception as error:
#     484         message = str(error)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/dataviz/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def drop_invalid_entries(path):
    """
    Removes entries from the dataset where the 'City' field is marked as 'N/A', 'Invalid Coords', or 'Error'.
    
    Args:
        path (str): The path to the JSON file containing the dataset.
    
    Returns:
        dict: The cleaned dataset.
    """
    
    try:
        with open(path, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: File not found at {path}")
        return None
    except json.JSONDecodeError:
        print(f"Error: Could not decode JSON from {path}")
        return None
    
    tot_removed = 0
    
    for year in data:
        for pollutant in data[year]:
            for country in data[year][pollutant]:
                original_len = len(data[year][pollutant][country])
                data[year][pollutant][country] = [
                    entry for entry in data[year][pollutant][country]
                    if entry.get("City") not in {"N/A", "Invalid Coords", "Error"}
                ]
                removed = original_len - len(data[year][pollutant][country])
                if removed > 0:
                    print(f"Removed {removed} invalid entries from {country}, {pollutant}, {year}")
                tot_removed += removed
    print(f"Total removed invalid entries: {tot_removed}")
    return data

# %%
new_data = drop_invalid_entries("../data/air_quality_data_with_cities.json")

with open("../data/cleaned_air_quality_data.json", 'w') as f:
    json.dump(new_data, f, indent=2)
print("Cleaned data saved to cleaned_air_quality_data.json")
# Out:
# Removed 4 invalid entries from Spain, O3, 2009
# Removed 4 invalid entries from Spain, O3, 2010
# Removed 4 invalid entries from Spain, O3, 2011
# Removed 1 invalid entries from Sweden, PM10, 2012
# Removed 1 invalid entries from Iceland, SO2, 2012
# Removed 1 invalid entries from Sweden, SO2, 2012
# Removed 2 invalid entries from Norway, SO2, 2012
# Removed 4 invalid entries from Greece, O3, 2012
# Removed 4 invalid entries from Spain, O3, 2012
# Removed 5 invalid entries from Greece, NO2, 2012
# Removed 1 invalid entries from Sweden, NO2, 2012
# Removed 1 invalid entries from Greece, CO, 2012
# Removed 5 invalid entries from Greece, NO, 2012
# Removed 6 invalid entries from United Kingdom, O3, 2013
# Removed 5 invalid entries from Greece, O3, 2013
# Removed 9 invalid entries from Sweden, O3, 2013
# Removed 1 invalid entries from Austria, O3, 2013
# Removed 4 invalid entries from Germany, O3, 2013
# Removed 6 invalid entries from Ireland, O3, 2013
# Removed 1 invalid entries from Italy, O3, 2013
# Removed 2 invalid entries from Norway, O3, 2013
# Removed 3 invalid entries from Poland, O3, 2013
# Removed 5 invalid entries from Spain, O3, 2013
# Removed 3 invalid entries from United Kingdom, NO2, 2013
# Removed 5 invalid entries from Greece, NO2, 2013
# Removed 3 invalid entries from Sweden, NO2, 2013
# Removed 1 invalid entries from Kosovo, NO2, 2013
# Removed 1 invalid entries from Austria, NO2, 2013
# Removed 4 invalid entries from Germany, NO2, 2013
# Removed 3 invalid entries from Ireland, NO2, 2013
# Removed 1 invalid entries from Italy, NO2, 2013
# Removed 2 invalid entries from Poland, NO2, 2013
# Removed 6 invalid entries from Spain, NO2, 2013
# Removed 2 invalid entries from Greece, CO, 2013
# Removed 1 invalid entries from Netherlands, CO, 2013
# Removed 1 invalid entries from Kosovo, CO, 2013
# Removed 1 invalid entries from Germany, CO, 2013
# Removed 1 invalid entries from Spain, CO, 2013
# Removed 2 invalid entries from Denmark, SO2, 2013
# Removed 1 invalid entries from Greece, SO2, 2013
# Removed 1 invalid entries from Iceland, SO2, 2013
# Removed 1 invalid entries from Netherlands, SO2, 2013
# Removed 1 invalid entries from Sweden, SO2, 2013
# Removed 1 invalid entries from Kosovo, SO2, 2013
# Removed 1 invalid entries from Germany, SO2, 2013
# Removed 1 invalid entries from Ireland, SO2, 2013
# Removed 2 invalid entries from Norway, SO2, 2013
# Removed 4 invalid entries from Poland, SO2, 2013
# Removed 5 invalid entries from Spain, SO2, 2013
# Removed 3 invalid entries from United Kingdom, PM10, 2013
# Removed 1 invalid entries from Estonia, PM10, 2013
# Removed 2 invalid entries from Iceland, PM10, 2013
# Removed 2 invalid entries from Netherlands, PM10, 2013
# Removed 3 invalid entries from Sweden, PM10, 2013
# Removed 1 invalid entries from Kosovo, PM10, 2013
# Removed 6 invalid entries from Germany, PM10, 2013
# Removed 3 invalid entries from Ireland, PM10, 2013
# Removed 1 invalid entries from Italy, PM10, 2013
# Removed 2 invalid entries from Poland, PM10, 2013
# Removed 5 invalid entries from Spain, PM10, 2013
# Removed 2 invalid entries from United Kingdom, PM2.5, 2013
# Removed 1 invalid entries from Bulgaria, PM2.5, 2013
# Removed 3 invalid entries from Estonia, PM2.5, 2013
# Removed 1 invalid entries from Netherlands, PM2.5, 2013
# Removed 2 invalid entries from Sweden, PM2.5, 2013
# Removed 1 invalid entries from Kosovo, PM2.5, 2013
# Removed 1 invalid entries from Germany, PM2.5, 2013
# Removed 2 invalid entries from Ireland, PM2.5, 2013
# Removed 1 invalid entries from Poland, PM2.5, 2013
# Removed 1 invalid entries from Spain, PM2.5, 2013
# Removed 5 invalid entries from Greece, NO, 2013
# Removed 1 invalid entries from Austria, NO, 2013
# Removed 4 invalid entries from Germany, NO, 2013
# Removed 6 invalid entries from Spain, NO, 2013
# Removed 1 invalid entries from Germany, NH3, 2013
# Removed 6 invalid entries from United Kingdom, O3, 2014
# Removed 5 invalid entries from Greece, O3, 2014
# Removed 11 invalid entries from Sweden, O3, 2014
# Removed 1 invalid entries from Austria, O3, 2014
# Removed 4 invalid entries from Germany, O3, 2014
# Removed 6 invalid entries from Ireland, O3, 2014
# Removed 1 invalid entries from Italy, O3, 2014
# Removed 2 invalid entries from Norway, O3, 2014
# Removed 3 invalid entries from Poland, O3, 2014
# Removed 5 invalid entries from Spain, O3, 2014
# Removed 3 invalid entries from United Kingdom, NO2, 2014
# Removed 5 invalid entries from Greece, NO2, 2014
# Removed 5 invalid entries from Sweden, NO2, 2014
# Removed 1 invalid entries from Austria, NO2, 2014
# Removed 4 invalid entries from Germany, NO2, 2014
# Removed 4 invalid entries from Ireland, NO2, 2014
# Removed 1 invalid entries from Italy, NO2, 2014
# Removed 3 invalid entries from Norway, NO2, 2014
# Removed 3 invalid entries from Poland, NO2, 2014
# Removed 7 invalid entries from Spain, NO2, 2014
# Removed 3 invalid entries from Greece, CO, 2014
# Removed 1 invalid entries from Germany, CO, 2014
# Removed 1 invalid entries from Spain, CO, 2014
# Removed 1 invalid entries from Greece, SO2, 2014
# Removed 1 invalid entries from Iceland, SO2, 2014
# Removed 1 invalid entries from Sweden, SO2, 2014
# Removed 1 invalid entries from Germany, SO2, 2014
# Removed 2 invalid entries from Ireland, SO2, 2014
# Removed 3 invalid entries from Norway, SO2, 2014
# Removed 3 invalid entries from Poland, SO2, 2014
# Removed 7 invalid entries from Spain, SO2, 2014
# Removed 3 invalid entries from United Kingdom, PM10, 2014
# Removed 1 invalid entries from Estonia, PM10, 2014
# Removed 1 invalid entries from Iceland, PM10, 2014
# Removed 1 invalid entries from Netherlands, PM10, 2014
# Removed 3 invalid entries from Sweden, PM10, 2014
# Removed 6 invalid entries from Germany, PM10, 2014
# Removed 4 invalid entries from Ireland, PM10, 2014
# Removed 1 invalid entries from Italy, PM10, 2014
# Removed 1 invalid entries from Norway, PM10, 2014
# Removed 1 invalid entries from Poland, PM10, 2014
# Removed 6 invalid entries from Spain, PM10, 2014
# Removed 2 invalid entries from United Kingdom, PM2.5, 2014
# Removed 1 invalid entries from Bulgaria, PM2.5, 2014
# Removed 3 invalid entries from Estonia, PM2.5, 2014
# Removed 1 invalid entries from Netherlands, PM2.5, 2014
# Removed 1 invalid entries from Sweden, PM2.5, 2014
# Removed 1 invalid entries from Germany, PM2.5, 2014
# Removed 2 invalid entries from Ireland, PM2.5, 2014
# Removed 1 invalid entries from Norway, PM2.5, 2014
# Removed 1 invalid entries from Poland, PM2.5, 2014
# Removed 3 invalid entries from Spain, PM2.5, 2014
# Removed 4 invalid entries from Greece, NO, 2014
# Removed 1 invalid entries from Austria, NO, 2014
# Removed 4 invalid entries from Germany, NO, 2014
# Removed 1 invalid entries from Norway, NO, 2014
# Removed 7 invalid entries from Spain, NO, 2014
# Removed 6 invalid entries from United Kingdom, O3, 2015
# Removed 1 invalid entries from Bulgaria, O3, 2015
# Removed 5 invalid entries from Greece, O3, 2015
# Removed 9 invalid entries from Sweden, O3, 2015
# Removed 1 invalid entries from Austria, O3, 2015
# Removed 4 invalid entries from Germany, O3, 2015
# Removed 6 invalid entries from Ireland, O3, 2015
# Removed 1 invalid entries from Italy, O3, 2015
# Removed 2 invalid entries from Norway, O3, 2015
# Removed 3 invalid entries from Poland, O3, 2015
# Removed 5 invalid entries from Spain, O3, 2015
# Removed 4 invalid entries from United Kingdom, NO2, 2015
# Removed 1 invalid entries from Bulgaria, NO2, 2015
# Removed 1 invalid entries from Estonia, NO2, 2015
# Removed 4 invalid entries from Greece, NO2, 2015
# Removed 2 invalid entries from Iceland, NO2, 2015
# Removed 1 invalid entries from Netherlands, NO2, 2015
# Removed 3 invalid entries from Sweden, NO2, 2015
# Removed 1 invalid entries from Austria, NO2, 2015
# Removed 4 invalid entries from Germany, NO2, 2015
# Removed 4 invalid entries from Ireland, NO2, 2015
# Removed 1 invalid entries from Italy, NO2, 2015
# Removed 3 invalid entries from Norway, NO2, 2015
# Removed 3 invalid entries from Poland, NO2, 2015
# Removed 7 invalid entries from Spain, NO2, 2015
# Removed 3 invalid entries from Greece, CO, 2015
# Removed 1 invalid entries from Germany, CO, 2015
# Removed 1 invalid entries from Ireland, CO, 2015
# Removed 1 invalid entries from Spain, CO, 2015
# Removed 2 invalid entries from Bulgaria, SO2, 2015
# Removed 1 invalid entries from Estonia, SO2, 2015
# Removed 1 invalid entries from Greece, SO2, 2015
# Removed 4 invalid entries from Iceland, SO2, 2015
# Removed 1 invalid entries from Netherlands, SO2, 2015
# Removed 1 invalid entries from Sweden, SO2, 2015
# Removed 1 invalid entries from Germany, SO2, 2015
# Removed 2 invalid entries from Ireland, SO2, 2015
# Removed 3 invalid entries from Norway, SO2, 2015
# Removed 3 invalid entries from Poland, SO2, 2015
# Removed 7 invalid entries from Spain, SO2, 2015
# Removed 3 invalid entries from United Kingdom, PM10, 2015
# Removed 1 invalid entries from Estonia, PM10, 2015
# Removed 2 invalid entries from Iceland, PM10, 2015
# Removed 1 invalid entries from Netherlands, PM10, 2015
# Removed 3 invalid entries from Sweden, PM10, 2015
# Removed 6 invalid entries from Germany, PM10, 2015
# Removed 3 invalid entries from Ireland, PM10, 2015
# Removed 1 invalid entries from Italy, PM10, 2015
# Removed 1 invalid entries from Norway, PM10, 2015
# Removed 1 invalid entries from Poland, PM10, 2015
# Removed 6 invalid entries from Spain, PM10, 2015
# Removed 4 invalid entries from United Kingdom, NO, 2015
# Removed 1 invalid entries from Bulgaria, NO, 2015
# Removed 5 invalid entries from Greece, NO, 2015
# Removed 2 invalid entries from Iceland, NO, 2015
# Removed 1 invalid entries from Austria, NO, 2015
# Removed 4 invalid entries from Germany, NO, 2015
# Removed 1 invalid entries from Norway, NO, 2015
# Removed 8 invalid entries from Spain, NO, 2015
# Removed 2 invalid entries from United Kingdom, PM2.5, 2015
# Removed 3 invalid entries from Estonia, PM2.5, 2015
# Removed 2 invalid entries from Iceland, PM2.5, 2015
# Removed 1 invalid entries from Sweden, PM2.5, 2015
# Removed 1 invalid entries from Germany, PM2.5, 2015
# Removed 2 invalid entries from Ireland, PM2.5, 2015
# Removed 1 invalid entries from Norway, PM2.5, 2015
# Removed 1 invalid entries from Poland, PM2.5, 2015
# Removed 3 invalid entries from Spain, PM2.5, 2015
# Removed 1 invalid entries from Greece, Pb, 2015
# Removed 6 invalid entries from United Kingdom, O3, 2016
# Removed 1 invalid entries from Bulgaria, O3, 2016
# Removed 1 invalid entries from Denmark, O3, 2016
# Removed 5 invalid entries from Greece, O3, 2016
# Removed 12 invalid entries from Sweden, O3, 2016
# Removed 1 invalid entries from Austria, O3, 2016
# Removed 4 invalid entries from Germany, O3, 2016
# Removed 6 invalid entries from Ireland, O3, 2016
# Removed 1 invalid entries from Italy, O3, 2016
# Removed 2 invalid entries from Norway, O3, 2016
# Removed 3 invalid entries from Poland, O3, 2016
# Removed 4 invalid entries from Spain, O3, 2016
# Removed 4 invalid entries from United Kingdom, NO2, 2016
# Removed 1 invalid entries from Bulgaria, NO2, 2016
# Removed 3 invalid entries from Denmark, NO2, 2016
# Removed 1 invalid entries from Estonia, NO2, 2016
# Removed 4 invalid entries from Greece, NO2, 2016
# Removed 2 invalid entries from Iceland, NO2, 2016
# Removed 1 invalid entries from Netherlands, NO2, 2016
# Removed 4 invalid entries from Sweden, NO2, 2016
# Removed 1 invalid entries from Austria, NO2, 2016
# Removed 4 invalid entries from Germany, NO2, 2016
# Removed 4 invalid entries from Ireland, NO2, 2016
# Removed 1 invalid entries from Italy, NO2, 2016
# Removed 4 invalid entries from Norway, NO2, 2016
# Removed 3 invalid entries from Poland, NO2, 2016
# Removed 7 invalid entries from Spain, NO2, 2016
# Removed 2 invalid entries from Greece, CO, 2016
# Removed 1 invalid entries from Germany, CO, 2016
# Removed 1 invalid entries from Ireland, CO, 2016
# Removed 1 invalid entries from Spain, CO, 2016
# Removed 2 invalid entries from Bulgaria, SO2, 2016
# Removed 1 invalid entries from Denmark, SO2, 2016
# Removed 1 invalid entries from Estonia, SO2, 2016
# Removed 4 invalid entries from Iceland, SO2, 2016
# Removed 1 invalid entries from Netherlands, SO2, 2016
# Removed 1 invalid entries from Sweden, SO2, 2016
# Removed 1 invalid entries from Germany, SO2, 2016
# Removed 2 invalid entries from Ireland, SO2, 2016
# Removed 3 invalid entries from Norway, SO2, 2016
# Removed 3 invalid entries from Poland, SO2, 2016
# Removed 7 invalid entries from Spain, SO2, 2016
# Removed 3 invalid entries from United Kingdom, PM10, 2016
# Removed 1 invalid entries from Estonia, PM10, 2016
# Removed 4 invalid entries from Greece, PM10, 2016
# Removed 2 invalid entries from Iceland, PM10, 2016
# Removed 1 invalid entries from Netherlands, PM10, 2016
# Removed 4 invalid entries from Sweden, PM10, 2016
# Removed 7 invalid entries from Germany, PM10, 2016
# Removed 3 invalid entries from Ireland, PM10, 2016
# Removed 1 invalid entries from Italy, PM10, 2016
# Removed 2 invalid entries from Norway, PM10, 2016
# Removed 1 invalid entries from Poland, PM10, 2016
# Removed 6 invalid entries from Spain, PM10, 2016
# Removed 4 invalid entries from United Kingdom, NO, 2016
# Removed 1 invalid entries from Bulgaria, NO, 2016
# Removed 1 invalid entries from Denmark, NO, 2016
# Removed 5 invalid entries from Greece, NO, 2016
# Removed 2 invalid entries from Iceland, NO, 2016
# Removed 1 invalid entries from Netherlands, NO, 2016
# Removed 1 invalid entries from Sweden, NO, 2016
# Removed 1 invalid entries from Austria, NO, 2016
# Removed 4 invalid entries from Germany, NO, 2016
# Removed 2 invalid entries from Norway, NO, 2016
# Removed 7 invalid entries from Spain, NO, 2016
# Removed 2 invalid entries from United Kingdom, PM2.5, 2016
# Removed 3 invalid entries from Estonia, PM2.5, 2016
# Removed 2 invalid entries from Greece, PM2.5, 2016
# Removed 2 invalid entries from Iceland, PM2.5, 2016
# Removed 4 invalid entries from Sweden, PM2.5, 2016
# Removed 1 invalid entries from Germany, PM2.5, 2016
# Removed 3 invalid entries from Ireland, PM2.5, 2016
# Removed 2 invalid entries from Norway, PM2.5, 2016
# Removed 1 invalid entries from Poland, PM2.5, 2016
# Removed 3 invalid entries from Spain, PM2.5, 2016
# Removed 6 invalid entries from United Kingdom, O3, 2017
# Removed 1 invalid entries from Bulgaria, O3, 2017
# Removed 4 invalid entries from Greece, O3, 2017
# Removed 10 invalid entries from Sweden, O3, 2017
# Removed 1 invalid entries from Austria, O3, 2017
# Removed 4 invalid entries from Germany, O3, 2017
# Removed 6 invalid entries from Ireland, O3, 2017
# Removed 1 invalid entries from Italy, O3, 2017
# Removed 2 invalid entries from Norway, O3, 2017
# Removed 3 invalid entries from Poland, O3, 2017
# Removed 4 invalid entries from Spain, O3, 2017
# Removed 4 invalid entries from United Kingdom, NO2, 2017
# Removed 1 invalid entries from Bulgaria, NO2, 2017
# Removed 1 invalid entries from Estonia, NO2, 2017
# Removed 5 invalid entries from Greece, NO2, 2017
# Removed 2 invalid entries from Iceland, NO2, 2017
# Removed 1 invalid entries from Netherlands, NO2, 2017
# Removed 6 invalid entries from Sweden, NO2, 2017
# Removed 1 invalid entries from Austria, NO2, 2017
# Removed 4 invalid entries from Germany, NO2, 2017
# Removed 3 invalid entries from Ireland, NO2, 2017
# Removed 1 invalid entries from Italy, NO2, 2017
# Removed 4 invalid entries from Norway, NO2, 2017
# Removed 3 invalid entries from Poland, NO2, 2017
# Removed 7 invalid entries from Spain, NO2, 2017
# Removed 2 invalid entries from Greece, CO, 2017
# Removed 1 invalid entries from Germany, CO, 2017
# Removed 1 invalid entries from Spain, CO, 2017
# Removed 2 invalid entries from Bulgaria, SO2, 2017
# Removed 1 invalid entries from Estonia, SO2, 2017
# Removed 5 invalid entries from Iceland, SO2, 2017
# Removed 1 invalid entries from Netherlands, SO2, 2017
# Removed 1 invalid entries from Sweden, SO2, 2017
# Removed 1 invalid entries from Germany, SO2, 2017
# Removed 1 invalid entries from Ireland, SO2, 2017
# Removed 3 invalid entries from Norway, SO2, 2017
# Removed 3 invalid entries from Poland, SO2, 2017
# Removed 7 invalid entries from Spain, SO2, 2017
# Removed 2 invalid entries from United Kingdom, PM10, 2017
# Removed 3 invalid entries from Bulgaria, PM10, 2017
# Removed 1 invalid entries from Estonia, PM10, 2017
# Removed 5 invalid entries from Greece, PM10, 2017
# Removed 2 invalid entries from Iceland, PM10, 2017
# Removed 1 invalid entries from Netherlands, PM10, 2017
# Removed 5 invalid entries from Sweden, PM10, 2017
# Removed 6 invalid entries from Germany, PM10, 2017
# Removed 2 invalid entries from Ireland, PM10, 2017
# Removed 1 invalid entries from Italy, PM10, 2017
# Removed 2 invalid entries from Norway, PM10, 2017
# Removed 1 invalid entries from Poland, PM10, 2017
# Removed 6 invalid entries from Spain, PM10, 2017
# Removed 4 invalid entries from United Kingdom, NO, 2017
# Removed 1 invalid entries from Bulgaria, NO, 2017
# Removed 5 invalid entries from Greece, NO, 2017
# Removed 2 invalid entries from Iceland, NO, 2017
# Removed 1 invalid entries from Netherlands, NO, 2017
# Removed 1 invalid entries from Sweden, NO, 2017
# Removed 1 invalid entries from Austria, NO, 2017
# Removed 4 invalid entries from Germany, NO, 2017
# Removed 2 invalid entries from Norway, NO, 2017
# Removed 7 invalid entries from Spain, NO, 2017
# Removed 1 invalid entries from United Kingdom, PM2.5, 2017
# Removed 1 invalid entries from Bulgaria, PM2.5, 2017
# Removed 3 invalid entries from Estonia, PM2.5, 2017
# Removed 2 invalid entries from Greece, PM2.5, 2017
# Removed 2 invalid entries from Iceland, PM2.5, 2017
# Removed 7 invalid entries from Sweden, PM2.5, 2017
# Removed 1 invalid entries from Germany, PM2.5, 2017
# Removed 3 invalid entries from Ireland, PM2.5, 2017
# Removed 2 invalid entries from Norway, PM2.5, 2017
# Removed 1 invalid entries from Poland, PM2.5, 2017
# Removed 3 invalid entries from Spain, PM2.5, 2017
# Removed 6 invalid entries from United Kingdom, O3, 2018
# Removed 1 invalid entries from Bulgaria, O3, 2018
# Removed 1 invalid entries from Denmark, O3, 2018
# Removed 3 invalid entries from Estonia, O3, 2018
# Removed 4 invalid entries from Greece, O3, 2018
# Removed 10 invalid entries from Sweden, O3, 2018
# Removed 1 invalid entries from Austria, O3, 2018
# Removed 4 invalid entries from Germany, O3, 2018
# Removed 8 invalid entries from Ireland, O3, 2018
# Removed 1 invalid entries from Italy, O3, 2018
# Removed 2 invalid entries from Norway, O3, 2018
# Removed 3 invalid entries from Poland, O3, 2018
# Removed 4 invalid entries from Spain, O3, 2018
# Removed 4 invalid entries from United Kingdom, NO2, 2018
# Removed 1 invalid entries from Bulgaria, NO2, 2018
# Removed 3 invalid entries from Denmark, NO2, 2018
# Removed 3 invalid entries from Estonia, NO2, 2018
# Removed 5 invalid entries from Greece, NO2, 2018
# Removed 2 invalid entries from Iceland, NO2, 2018
# Removed 1 invalid entries from Netherlands, NO2, 2018
# Removed 5 invalid entries from Sweden, NO2, 2018
# Removed 1 invalid entries from Austria, NO2, 2018
# Removed 4 invalid entries from Germany, NO2, 2018
# Removed 3 invalid entries from Ireland, NO2, 2018
# Removed 1 invalid entries from Italy, NO2, 2018
# Removed 4 invalid entries from Norway, NO2, 2018
# Removed 3 invalid entries from Poland, NO2, 2018
# Removed 6 invalid entries from Spain, NO2, 2018
# Removed 1 invalid entries from Estonia, CO, 2018
# Removed 2 invalid entries from Greece, CO, 2018
# Removed 1 invalid entries from Germany, CO, 2018
# Removed 1 invalid entries from Spain, CO, 2018
# Removed 2 invalid entries from Bulgaria, SO2, 2018
# Removed 1 invalid entries from Denmark, SO2, 2018
# Removed 3 invalid entries from Estonia, SO2, 2018
# Removed 5 invalid entries from Iceland, SO2, 2018
# Removed 1 invalid entries from Netherlands, SO2, 2018
# Removed 1 invalid entries from Sweden, SO2, 2018
# Removed 1 invalid entries from Germany, SO2, 2018
# Removed 1 invalid entries from Ireland, SO2, 2018
# Removed 3 invalid entries from Norway, SO2, 2018
# Removed 3 invalid entries from Poland, SO2, 2018
# Removed 6 invalid entries from Spain, SO2, 2018
# Removed 2 invalid entries from United Kingdom, PM10, 2018
# Removed 3 invalid entries from Bulgaria, PM10, 2018
# Removed 1 invalid entries from Estonia, PM10, 2018
# Removed 5 invalid entries from Greece, PM10, 2018
# Removed 2 invalid entries from Iceland, PM10, 2018
# Removed 1 invalid entries from Netherlands, PM10, 2018
# Removed 4 invalid entries from Sweden, PM10, 2018
# Removed 6 invalid entries from Germany, PM10, 2018
# Removed 5 invalid entries from Ireland, PM10, 2018
# Removed 1 invalid entries from Italy, PM10, 2018
# Removed 2 invalid entries from Norway, PM10, 2018
# Removed 1 invalid entries from Poland, PM10, 2018
# Removed 5 invalid entries from Spain, PM10, 2018
# Removed 4 invalid entries from United Kingdom, NO, 2018
# Removed 1 invalid entries from Bulgaria, NO, 2018
# Removed 1 invalid entries from Denmark, NO, 2018
# Removed 5 invalid entries from Greece, NO, 2018
# Removed 2 invalid entries from Iceland, NO, 2018
# Removed 1 invalid entries from Netherlands, NO, 2018
# Removed 1 invalid entries from Austria, NO, 2018
# Removed 4 invalid entries from Germany, NO, 2018
# Removed 1 invalid entries from Italy, NO, 2018
# Removed 2 invalid entries from Norway, NO, 2018
# Removed 6 invalid entries from Spain, NO, 2018
# Removed 2 invalid entries from United Kingdom, PM2.5, 2018
# Removed 1 invalid entries from Bulgaria, PM2.5, 2018
# Removed 3 invalid entries from Estonia, PM2.5, 2018
# Removed 1 invalid entries from Greece, PM2.5, 2018
# Removed 2 invalid entries from Iceland, PM2.5, 2018
# Removed 4 invalid entries from Sweden, PM2.5, 2018
# Removed 1 invalid entries from Germany, PM2.5, 2018
# Removed 6 invalid entries from Ireland, PM2.5, 2018
# Removed 2 invalid entries from Norway, PM2.5, 2018
# Removed 1 invalid entries from Poland, PM2.5, 2018
# Removed 2 invalid entries from Spain, PM2.5, 2018
# Removed 6 invalid entries from United Kingdom, O3, 2019
# Removed 1 invalid entries from Bulgaria, O3, 2019
# Removed 1 invalid entries from Denmark, O3, 2019
# Removed 3 invalid entries from Estonia, O3, 2019
# Removed 4 invalid entries from Greece, O3, 2019
# Removed 10 invalid entries from Sweden, O3, 2019
# Removed 1 invalid entries from Kosovo, O3, 2019
# Removed 1 invalid entries from Austria, O3, 2019
# Removed 4 invalid entries from Germany, O3, 2019
# Removed 8 invalid entries from Ireland, O3, 2019
# Removed 1 invalid entries from Italy, O3, 2019
# Removed 2 invalid entries from Norway, O3, 2019
# Removed 3 invalid entries from Poland, O3, 2019
# Removed 4 invalid entries from Spain, O3, 2019
# Removed 4 invalid entries from United Kingdom, NO2, 2019
# Removed 1 invalid entries from Bulgaria, NO2, 2019
# Removed 3 invalid entries from Denmark, NO2, 2019
# Removed 3 invalid entries from Estonia, NO2, 2019
# Removed 5 invalid entries from Greece, NO2, 2019
# Removed 2 invalid entries from Iceland, NO2, 2019
# Removed 1 invalid entries from Netherlands, NO2, 2019
# Removed 5 invalid entries from Sweden, NO2, 2019
# Removed 1 invalid entries from Kosovo, NO2, 2019
# Removed 1 invalid entries from Austria, NO2, 2019
# Removed 4 invalid entries from Germany, NO2, 2019
# Removed 3 invalid entries from Ireland, NO2, 2019
# Removed 1 invalid entries from Italy, NO2, 2019
# Removed 4 invalid entries from Norway, NO2, 2019
# Removed 3 invalid entries from Poland, NO2, 2019
# Removed 6 invalid entries from Spain, NO2, 2019
# Removed 1 invalid entries from Estonia, CO, 2019
# Removed 2 invalid entries from Greece, CO, 2019
# Removed 1 invalid entries from Kosovo, CO, 2019
# Removed 1 invalid entries from Germany, CO, 2019
# Removed 1 invalid entries from Spain, CO, 2019
# Removed 2 invalid entries from Bulgaria, SO2, 2019
# Removed 2 invalid entries from Denmark, SO2, 2019
# Removed 3 invalid entries from Estonia, SO2, 2019
# Removed 4 invalid entries from Iceland, SO2, 2019
# Removed 1 invalid entries from Netherlands, SO2, 2019
# Removed 5 invalid entries from Sweden, SO2, 2019
# Removed 1 invalid entries from Kosovo, SO2, 2019
# Removed 1 invalid entries from Germany, SO2, 2019
# Removed 1 invalid entries from Ireland, SO2, 2019
# Removed 3 invalid entries from Norway, SO2, 2019
# Removed 3 invalid entries from Poland, SO2, 2019
# Removed 6 invalid entries from Spain, SO2, 2019
# Removed 2 invalid entries from United Kingdom, PM10, 2019
# Removed 3 invalid entries from Bulgaria, PM10, 2019
# Removed 1 invalid entries from Estonia, PM10, 2019
# Removed 4 invalid entries from Greece, PM10, 2019
# Removed 2 invalid entries from Iceland, PM10, 2019
# Removed 1 invalid entries from Netherlands, PM10, 2019
# Removed 5 invalid entries from Sweden, PM10, 2019
# Removed 1 invalid entries from Kosovo, PM10, 2019
# Removed 6 invalid entries from Germany, PM10, 2019
# Removed 5 invalid entries from Ireland, PM10, 2019
# Removed 1 invalid entries from Italy, PM10, 2019
# Removed 2 invalid entries from Norway, PM10, 2019
# Removed 1 invalid entries from Poland, PM10, 2019
# Removed 5 invalid entries from Spain, PM10, 2019
# Removed 4 invalid entries from United Kingdom, NO, 2019
# Removed 1 invalid entries from Bulgaria, NO, 2019
# Removed 2 invalid entries from Denmark, NO, 2019
# Removed 5 invalid entries from Greece, NO, 2019
# Removed 2 invalid entries from Iceland, NO, 2019
# Removed 1 invalid entries from Netherlands, NO, 2019
# Removed 1 invalid entries from Kosovo, NO, 2019
# Removed 1 invalid entries from Austria, NO, 2019
# Removed 4 invalid entries from Germany, NO, 2019
# Removed 1 invalid entries from Italy, NO, 2019
# Removed 2 invalid entries from Norway, NO, 2019
# Removed 3 invalid entries from Poland, NO, 2019
# Removed 6 invalid entries from Spain, NO, 2019
# Removed 2 invalid entries from United Kingdom, PM2.5, 2019
# Removed 1 invalid entries from Bulgaria, PM2.5, 2019
# Removed 1 invalid entries from Denmark, PM2.5, 2019
# Removed 3 invalid entries from Estonia, PM2.5, 2019
# Removed 1 invalid entries from Greece, PM2.5, 2019
# Removed 2 invalid entries from Iceland, PM2.5, 2019
# Removed 5 invalid entries from Sweden, PM2.5, 2019
# Removed 1 invalid entries from Kosovo, PM2.5, 2019
# Removed 1 invalid entries from Germany, PM2.5, 2019
# Removed 6 invalid entries from Ireland, PM2.5, 2019
# Removed 2 invalid entries from Norway, PM2.5, 2019
# Removed 1 invalid entries from Poland, PM2.5, 2019
# Removed 2 invalid entries from Spain, PM2.5, 2019
# Removed 1 invalid entries from Estonia, CO, 2020
# Removed 2 invalid entries from Greece, CO, 2020
# Removed 1 invalid entries from Kosovo, CO, 2020
# Removed 1 invalid entries from Germany, CO, 2020
# Removed 1 invalid entries from Spain, CO, 2020
# Removed 6 invalid entries from United Kingdom, O3, 2020
# Removed 1 invalid entries from Bulgaria, O3, 2020
# Removed 1 invalid entries from Denmark, O3, 2020
# Removed 3 invalid entries from Estonia, O3, 2020
# Removed 5 invalid entries from Greece, O3, 2020
# Removed 10 invalid entries from Sweden, O3, 2020
# Removed 1 invalid entries from Kosovo, O3, 2020
# Removed 1 invalid entries from Austria, O3, 2020
# Removed 4 invalid entries from Germany, O3, 2020
# Removed 8 invalid entries from Ireland, O3, 2020
# Removed 1 invalid entries from Italy, O3, 2020
# Removed 3 invalid entries from Norway, O3, 2020
# Removed 3 invalid entries from Poland, O3, 2020
# Removed 4 invalid entries from Spain, O3, 2020
# Removed 4 invalid entries from United Kingdom, NO2, 2020
# Removed 1 invalid entries from Bulgaria, NO2, 2020
# Removed 3 invalid entries from Denmark, NO2, 2020
# Removed 3 invalid entries from Estonia, NO2, 2020
# Removed 4 invalid entries from Greece, NO2, 2020
# Removed 2 invalid entries from Iceland, NO2, 2020
# Removed 1 invalid entries from Netherlands, NO2, 2020
# Removed 5 invalid entries from Sweden, NO2, 2020
# Removed 1 invalid entries from Kosovo, NO2, 2020
# Removed 1 invalid entries from Austria, NO2, 2020
# Removed 4 invalid entries from Germany, NO2, 2020
# Removed 3 invalid entries from Ireland, NO2, 2020
# Removed 1 invalid entries from Italy, NO2, 2020
# Removed 4 invalid entries from Norway, NO2, 2020
# Removed 3 invalid entries from Poland, NO2, 2020
# Removed 6 invalid entries from Spain, NO2, 2020
# Removed 2 invalid entries from United Kingdom, PM10, 2020
# Removed 3 invalid entries from Bulgaria, PM10, 2020
# Removed 1 invalid entries from Estonia, PM10, 2020
# Removed 5 invalid entries from Greece, PM10, 2020
# Removed 2 invalid entries from Iceland, PM10, 2020
# Removed 1 invalid entries from Netherlands, PM10, 2020
# Removed 5 invalid entries from Sweden, PM10, 2020
# Removed 1 invalid entries from Kosovo, PM10, 2020
# Removed 6 invalid entries from Germany, PM10, 2020
# Removed 8 invalid entries from Ireland, PM10, 2020
# Removed 1 invalid entries from Italy, PM10, 2020
# Removed 2 invalid entries from Norway, PM10, 2020
# Removed 2 invalid entries from Poland, PM10, 2020
# Removed 5 invalid entries from Spain, PM10, 2020
# Removed 2 invalid entries from Bulgaria, SO2, 2020
# Removed 2 invalid entries from Denmark, SO2, 2020
# Removed 3 invalid entries from Estonia, SO2, 2020
# Removed 4 invalid entries from Iceland, SO2, 2020
# Removed 1 invalid entries from Netherlands, SO2, 2020
# Removed 3 invalid entries from Sweden, SO2, 2020
# Removed 1 invalid entries from Kosovo, SO2, 2020
# Removed 1 invalid entries from Germany, SO2, 2020
# Removed 1 invalid entries from Ireland, SO2, 2020
# Removed 3 invalid entries from Norway, SO2, 2020
# Removed 3 invalid entries from Poland, SO2, 2020
# Removed 6 invalid entries from Spain, SO2, 2020
# Removed 4 invalid entries from United Kingdom, NO, 2020
# Removed 1 invalid entries from Bulgaria, NO, 2020
# Removed 2 invalid entries from Denmark, NO, 2020
# Removed 5 invalid entries from Greece, NO, 2020
# Removed 2 invalid entries from Iceland, NO, 2020
# Removed 1 invalid entries from Netherlands, NO, 2020
# Removed 1 invalid entries from Kosovo, NO, 2020
# Removed 1 invalid entries from Austria, NO, 2020
# Removed 4 invalid entries from Germany, NO, 2020
# Removed 1 invalid entries from Italy, NO, 2020
# Removed 2 invalid entries from Norway, NO, 2020
# Removed 3 invalid entries from Poland, NO, 2020
# Removed 6 invalid entries from Spain, NO, 2020
# Removed 2 invalid entries from United Kingdom, PM2.5, 2020
# Removed 1 invalid entries from Bulgaria, PM2.5, 2020
# Removed 1 invalid entries from Denmark, PM2.5, 2020
# Removed 3 invalid entries from Estonia, PM2.5, 2020
# Removed 2 invalid entries from Greece, PM2.5, 2020
# Removed 2 invalid entries from Iceland, PM2.5, 2020
# Removed 4 invalid entries from Sweden, PM2.5, 2020
# Removed 1 invalid entries from Kosovo, PM2.5, 2020
# Removed 1 invalid entries from Germany, PM2.5, 2020
# Removed 9 invalid entries from Ireland, PM2.5, 2020
# Removed 2 invalid entries from Norway, PM2.5, 2020
# Removed 1 invalid entries from Poland, PM2.5, 2020
# Removed 2 invalid entries from Spain, PM2.5, 2020
# Removed 1 invalid entries from Bulgaria, PM2.5, 2021
# Removed 1 invalid entries from Denmark, PM2.5, 2021
# Removed 3 invalid entries from Estonia, PM2.5, 2021
# Removed 2 invalid entries from Greece, PM2.5, 2021
# Removed 2 invalid entries from Iceland, PM2.5, 2021
# Removed 4 invalid entries from Sweden, PM2.5, 2021
# Removed 1 invalid entries from Slovakia, PM2.5, 2021
# Removed 1 invalid entries from Kosovo, PM2.5, 2021
# Removed 2 invalid entries from Germany, PM2.5, 2021
# Removed 8 invalid entries from Ireland, PM2.5, 2021
# Removed 2 invalid entries from Norway, PM2.5, 2021
# Removed 1 invalid entries from Poland, PM2.5, 2021
# Removed 2 invalid entries from Spain, PM2.5, 2021
# Removed 3 invalid entries from Bulgaria, PM10, 2021
# Removed 1 invalid entries from Estonia, PM10, 2021
# Removed 5 invalid entries from Greece, PM10, 2021
# Removed 2 invalid entries from Iceland, PM10, 2021
# Removed 1 invalid entries from Netherlands, PM10, 2021
# Removed 5 invalid entries from Sweden, PM10, 2021
# Removed 1 invalid entries from Slovakia, PM10, 2021
# Removed 1 invalid entries from Kosovo, PM10, 2021
# Removed 6 invalid entries from Germany, PM10, 2021
# Removed 8 invalid entries from Ireland, PM10, 2021
# Removed 1 invalid entries from Italy, PM10, 2021
# Removed 2 invalid entries from Norway, PM10, 2021
# Removed 2 invalid entries from Poland, PM10, 2021
# Removed 5 invalid entries from Spain, PM10, 2021
# Removed 1 invalid entries from Bulgaria, NO2, 2021
# Removed 3 invalid entries from Denmark, NO2, 2021
# Removed 3 invalid entries from Estonia, NO2, 2021
# Removed 4 invalid entries from Greece, NO2, 2021
# Removed 2 invalid entries from Iceland, NO2, 2021
# Removed 1 invalid entries from Netherlands, NO2, 2021
# Removed 5 invalid entries from Sweden, NO2, 2021
# Removed 1 invalid entries from Slovakia, NO2, 2021
# Removed 1 invalid entries from Kosovo, NO2, 2021
# Removed 1 invalid entries from Austria, NO2, 2021
# Removed 4 invalid entries from Germany, NO2, 2021
# Removed 3 invalid entries from Ireland, NO2, 2021
# Removed 1 invalid entries from Italy, NO2, 2021
# Removed 4 invalid entries from Norway, NO2, 2021
# Removed 3 invalid entries from Poland, NO2, 2021
# Removed 6 invalid entries from Spain, NO2, 2021
# Removed 2 invalid entries from Bulgaria, SO2, 2021
# Removed 2 invalid entries from Denmark, SO2, 2021
# Removed 3 invalid entries from Estonia, SO2, 2021
# Removed 4 invalid entries from Iceland, SO2, 2021
# Removed 1 invalid entries from Netherlands, SO2, 2021
# Removed 3 invalid entries from Sweden, SO2, 2021
# Removed 1 invalid entries from Kosovo, SO2, 2021
# Removed 1 invalid entries from Germany, SO2, 2021
# Removed 1 invalid entries from Ireland, SO2, 2021
# Removed 3 invalid entries from Norway, SO2, 2021
# Removed 3 invalid entries from Poland, SO2, 2021
# Removed 6 invalid entries from Spain, SO2, 2021
# Removed 1 invalid entries from Estonia, CO, 2021
# Removed 2 invalid entries from Greece, CO, 2021
# Removed 1 invalid entries from Kosovo, CO, 2021
# Removed 1 invalid entries from Germany, CO, 2021
# Removed 1 invalid entries from Spain, CO, 2021
# Removed 1 invalid entries from Bulgaria, O3, 2021
# Removed 1 invalid entries from Denmark, O3, 2021
# Removed 3 invalid entries from Estonia, O3, 2021
# Removed 4 invalid entries from Greece, O3, 2021
# Removed 10 invalid entries from Sweden, O3, 2021
# Removed 1 invalid entries from Slovakia, O3, 2021
# Removed 1 invalid entries from Kosovo, O3, 2021
# Removed 1 invalid entries from Austria, O3, 2021
# Removed 4 invalid entries from Germany, O3, 2021
# Removed 8 invalid entries from Ireland, O3, 2021
# Removed 1 invalid entries from Italy, O3, 2021
# Removed 2 invalid entries from Norway, O3, 2021
# Removed 3 invalid entries from Poland, O3, 2021
# Removed 4 invalid entries from Spain, O3, 2021
# Removed 1 invalid entries from Bulgaria, NO, 2021
# Removed 2 invalid entries from Denmark, NO, 2021
# Removed 5 invalid entries from Greece, NO, 2021
# Removed 2 invalid entries from Iceland, NO, 2021
# Removed 1 invalid entries from Netherlands, NO, 2021
# Removed 1 invalid entries from Kosovo, NO, 2021
# Removed 1 invalid entries from Austria, NO, 2021
# Removed 4 invalid entries from Germany, NO, 2021
# Removed 1 invalid entries from Italy, NO, 2021
# Removed 2 invalid entries from Norway, NO, 2021
# Removed 3 invalid entries from Poland, NO, 2021
# Removed 6 invalid entries from Spain, NO, 2021
# Removed 1 invalid entries from Bulgaria, PM2.5, 2022
# Removed 1 invalid entries from Denmark, PM2.5, 2022
# Removed 3 invalid entries from Estonia, PM2.5, 2022
# Removed 2 invalid entries from Greece, PM2.5, 2022
# Removed 2 invalid entries from Iceland, PM2.5, 2022
# Removed 4 invalid entries from Sweden, PM2.5, 2022
# Removed 1 invalid entries from Slovakia, PM2.5, 2022
# Removed 1 invalid entries from Kosovo, PM2.5, 2022
# Removed 4 invalid entries from Germany, PM2.5, 2022
# Removed 14 invalid entries from Ireland, PM2.5, 2022
# Removed 1 invalid entries from Norway, PM2.5, 2022
# Removed 1 invalid entries from Poland, PM2.5, 2022
# Removed 2 invalid entries from Spain, PM2.5, 2022
# Removed 3 invalid entries from Bulgaria, PM10, 2022
# Removed 1 invalid entries from Estonia, PM10, 2022
# Removed 5 invalid entries from Greece, PM10, 2022
# Removed 2 invalid entries from Iceland, PM10, 2022
# Removed 1 invalid entries from Netherlands, PM10, 2022
# Removed 5 invalid entries from Sweden, PM10, 2022
# Removed 1 invalid entries from Slovakia, PM10, 2022
# Removed 1 invalid entries from Kosovo, PM10, 2022
# Removed 6 invalid entries from Germany, PM10, 2022
# Removed 16 invalid entries from Ireland, PM10, 2022
# Removed 1 invalid entries from Italy, PM10, 2022
# Removed 1 invalid entries from Norway, PM10, 2022
# Removed 2 invalid entries from Poland, PM10, 2022
# Removed 5 invalid entries from Spain, PM10, 2022
# Removed 1 invalid entries from Estonia, CO, 2022
# Removed 2 invalid entries from Greece, CO, 2022
# Removed 1 invalid entries from Kosovo, CO, 2022
# Removed 1 invalid entries from Germany, CO, 2022
# Removed 1 invalid entries from Ireland, CO, 2022
# Removed 1 invalid entries from Spain, CO, 2022
# Removed 2 invalid entries from Bulgaria, SO2, 2022
# Removed 2 invalid entries from Denmark, SO2, 2022
# Removed 3 invalid entries from Estonia, SO2, 2022
# Removed 4 invalid entries from Iceland, SO2, 2022
# Removed 1 invalid entries from Netherlands, SO2, 2022
# Removed 5 invalid entries from Sweden, SO2, 2022
# Removed 1 invalid entries from Kosovo, SO2, 2022
# Removed 1 invalid entries from Germany, SO2, 2022
# Removed 4 invalid entries from Ireland, SO2, 2022
# Removed 2 invalid entries from Norway, SO2, 2022
# Removed 3 invalid entries from Poland, SO2, 2022
# Removed 6 invalid entries from Spain, SO2, 2022
# Removed 1 invalid entries from Bulgaria, NO2, 2022
# Removed 3 invalid entries from Denmark, NO2, 2022
# Removed 3 invalid entries from Estonia, NO2, 2022
# Removed 5 invalid entries from Greece, NO2, 2022
# Removed 2 invalid entries from Iceland, NO2, 2022
# Removed 1 invalid entries from Netherlands, NO2, 2022
# Removed 4 invalid entries from Sweden, NO2, 2022
# Removed 1 invalid entries from Slovakia, NO2, 2022
# Removed 1 invalid entries from Kosovo, NO2, 2022
# Removed 1 invalid entries from Austria, NO2, 2022
# Removed 4 invalid entries from Germany, NO2, 2022
# Removed 7 invalid entries from Ireland, NO2, 2022
# Removed 1 invalid entries from Italy, NO2, 2022
# Removed 2 invalid entries from Norway, NO2, 2022
# Removed 3 invalid entries from Poland, NO2, 2022
# Removed 6 invalid entries from Spain, NO2, 2022
# Removed 1 invalid entries from Bulgaria, O3, 2022
# Removed 1 invalid entries from Denmark, O3, 2022
# Removed 3 invalid entries from Estonia, O3, 2022
# Removed 5 invalid entries from Greece, O3, 2022
# Removed 10 invalid entries from Sweden, O3, 2022
# Removed 1 invalid entries from Slovakia, O3, 2022
# Removed 1 invalid entries from Kosovo, O3, 2022
# Removed 1 invalid entries from Austria, O3, 2022
# Removed 4 invalid entries from Germany, O3, 2022
# Removed 10 invalid entries from Ireland, O3, 2022
# Removed 1 invalid entries from Italy, O3, 2022
# Removed 2 invalid entries from Norway, O3, 2022
# Removed 3 invalid entries from Poland, O3, 2022
# Removed 4 invalid entries from Spain, O3, 2022
# Removed 1 invalid entries from Bulgaria, NO, 2022
# Removed 2 invalid entries from Denmark, NO, 2022
# Removed 4 invalid entries from Greece, NO, 2022
# Removed 2 invalid entries from Iceland, NO, 2022
# Removed 1 invalid entries from Netherlands, NO, 2022
# Removed 1 invalid entries from Kosovo, NO, 2022
# Removed 1 invalid entries from Austria, NO, 2022
# Removed 4 invalid entries from Germany, NO, 2022
# Removed 1 invalid entries from Italy, NO, 2022
# Removed 1 invalid entries from Norway, NO, 2022
# Removed 3 invalid entries from Poland, NO, 2022
# Removed 6 invalid entries from Spain, NO, 2022
# Removed 1 invalid entries from Bulgaria, PM2.5, 2023
# Removed 1 invalid entries from Denmark, PM2.5, 2023
# Removed 3 invalid entries from Estonia, PM2.5, 2023
# Removed 2 invalid entries from Greece, PM2.5, 2023
# Removed 2 invalid entries from Iceland, PM2.5, 2023
# Removed 1 invalid entries from Netherlands, PM2.5, 2023
# Removed 4 invalid entries from Sweden, PM2.5, 2023
# Removed 1 invalid entries from Slovakia, PM2.5, 2023
# Removed 1 invalid entries from Kosovo, PM2.5, 2023
# Removed 4 invalid entries from Germany, PM2.5, 2023
# Removed 20 invalid entries from Ireland, PM2.5, 2023
# Removed 1 invalid entries from Norway, PM2.5, 2023
# Removed 1 invalid entries from Poland, PM2.5, 2023
# Removed 2 invalid entries from Spain, PM2.5, 2023
# Removed 3 invalid entries from Bulgaria, PM10, 2023
# Removed 1 invalid entries from Estonia, PM10, 2023
# Removed 5 invalid entries from Greece, PM10, 2023
# Removed 2 invalid entries from Iceland, PM10, 2023
# Removed 2 invalid entries from Netherlands, PM10, 2023
# Removed 6 invalid entries from Sweden, PM10, 2023
# Removed 1 invalid entries from Slovakia, PM10, 2023
# Removed 1 invalid entries from Kosovo, PM10, 2023
# Removed 6 invalid entries from Germany, PM10, 2023
# Removed 21 invalid entries from Ireland, PM10, 2023
# Removed 1 invalid entries from Italy, PM10, 2023
# Removed 1 invalid entries from Norway, PM10, 2023
# Removed 2 invalid entries from Poland, PM10, 2023
# Removed 4 invalid entries from Spain, PM10, 2023
# Removed 1 invalid entries from Estonia, CO, 2023
# Removed 2 invalid entries from Greece, CO, 2023
# Removed 1 invalid entries from Kosovo, CO, 2023
# Removed 1 invalid entries from Germany, CO, 2023
# Removed 1 invalid entries from Ireland, CO, 2023
# Removed 1 invalid entries from Spain, CO, 2023
# Removed 2 invalid entries from Bulgaria, SO2, 2023
# Removed 2 invalid entries from Denmark, SO2, 2023
# Removed 3 invalid entries from Estonia, SO2, 2023
# Removed 4 invalid entries from Iceland, SO2, 2023
# Removed 1 invalid entries from Netherlands, SO2, 2023
# Removed 5 invalid entries from Sweden, SO2, 2023
# Removed 1 invalid entries from Kosovo, SO2, 2023
# Removed 1 invalid entries from Germany, SO2, 2023
# Removed 4 invalid entries from Ireland, SO2, 2023
# Removed 2 invalid entries from Norway, SO2, 2023
# Removed 3 invalid entries from Poland, SO2, 2023
# Removed 5 invalid entries from Spain, SO2, 2023
# Removed 1 invalid entries from Bulgaria, NO2, 2023
# Removed 3 invalid entries from Denmark, NO2, 2023
# Removed 3 invalid entries from Estonia, NO2, 2023
# Removed 5 invalid entries from Greece, NO2, 2023
# Removed 2 invalid entries from Iceland, NO2, 2023
# Removed 2 invalid entries from Netherlands, NO2, 2023
# Removed 6 invalid entries from Sweden, NO2, 2023
# Removed 1 invalid entries from Slovakia, NO2, 2023
# Removed 1 invalid entries from Kosovo, NO2, 2023
# Removed 1 invalid entries from Austria, NO2, 2023
# Removed 4 invalid entries from Germany, NO2, 2023
# Removed 8 invalid entries from Ireland, NO2, 2023
# Removed 1 invalid entries from Italy, NO2, 2023
# Removed 3 invalid entries from Norway, NO2, 2023
# Removed 3 invalid entries from Poland, NO2, 2023
# Removed 5 invalid entries from Spain, NO2, 2023
# Removed 1 invalid entries from Bulgaria, O3, 2023
# Removed 1 invalid entries from Denmark, O3, 2023
# Removed 3 invalid entries from Estonia, O3, 2023
# Removed 4 invalid entries from Greece, O3, 2023
# Removed 10 invalid entries from Sweden, O3, 2023
# Removed 1 invalid entries from Slovakia, O3, 2023
# Removed 1 invalid entries from Kosovo, O3, 2023
# Removed 1 invalid entries from Austria, O3, 2023
# Removed 4 invalid entries from Germany, O3, 2023
# Removed 11 invalid entries from Ireland, O3, 2023
# Removed 1 invalid entries from Italy, O3, 2023
# Removed 3 invalid entries from Norway, O3, 2023
# Removed 3 invalid entries from Poland, O3, 2023
# Removed 4 invalid entries from Spain, O3, 2023
# Removed 1 invalid entries from Bulgaria, NO, 2023
# Removed 2 invalid entries from Denmark, NO, 2023
# Removed 5 invalid entries from Greece, NO, 2023
# Removed 2 invalid entries from Iceland, NO, 2023
# Removed 2 invalid entries from Netherlands, NO, 2023
# Removed 1 invalid entries from Kosovo, NO, 2023
# Removed 1 invalid entries from Austria, NO, 2023
# Removed 4 invalid entries from Germany, NO, 2023
# Removed 1 invalid entries from Italy, NO, 2023
# Removed 1 invalid entries from Norway, NO, 2023
# Removed 3 invalid entries from Poland, NO, 2023
# Removed 5 invalid entries from Spain, NO, 2023
# Removed 1 invalid entries from Estonia, PM10, 2024
# Removed 2 invalid entries from Iceland, PM10, 2024
# Removed 1 invalid entries from Slovakia, PM10, 2024
# Removed 3 invalid entries from Spain, PM10, 2024
# Removed 3 invalid entries from Estonia, NO2, 2024
# Removed 2 invalid entries from Iceland, NO2, 2024
# Removed 1 invalid entries from Slovakia, NO2, 2024
# Removed 6 invalid entries from Ireland, NO2, 2024
# Removed 5 invalid entries from Spain, NO2, 2024
# Removed 3 invalid entries from Estonia, PM2.5, 2024
# Removed 2 invalid entries from Iceland, PM2.5, 2024
# Removed 1 invalid entries from Slovakia, PM2.5, 2024
# Removed 1 invalid entries from Spain, PM2.5, 2024
# Removed 3 invalid entries from Estonia, SO2, 2024
# Removed 3 invalid entries from Iceland, SO2, 2024
# Removed 4 invalid entries from Ireland, SO2, 2024
# Removed 4 invalid entries from Spain, SO2, 2024
# Removed 1 invalid entries from Estonia, CO, 2024
# Removed 1 invalid entries from Ireland, CO, 2024
# Removed 1 invalid entries from Spain, CO, 2024
# Removed 3 invalid entries from Estonia, O3, 2024
# Removed 1 invalid entries from Slovakia, O3, 2024
# Removed 9 invalid entries from Ireland, O3, 2024
# Removed 3 invalid entries from Spain, O3, 2024
# Removed 2 invalid entries from Iceland, NO, 2024
# Removed 5 invalid entries from Spain, NO, 2024
# Total removed invalid entries: 2458
# Cleaned data saved to cleaned_air_quality_data.json
